# %% [markdown]
# # PROJET PYTHON

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score, silhouette_score, silhouette_samples
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore')

# %%
erp = pd.read_excel('erp.xlsx')
liaison = pd.read_excel('liaison.xlsx')
web = pd.read_excel('web.xlsx')

# %%
print("les dimensions des datasets sont :\n\nerp : {}\nliason : {}\nweb : {}".format(erp.shape,liaison.shape, web.shape),
     "\n\nles colonnes des datasets sont :\n\nerp : {}\nliason:{}\nweb : {}".format(erp.columns,liaison.columns, web.columns))
# Out:
# les dimensions des datasets sont :
#
# erp : (825, 5)
# liason : (825, 2)
# web : (1513, 28)
#
# les colonnes des datasets sont :
#
# erp : Index(['product_id', 'onsale_web', 'price', 'stock_quantity', 'stock_status'], dtype='object')
# liason:Index(['product_id', 'id_web'], dtype='object')
# web : Index(['sku', 'virtual', 'downloadable', 'rating_count', 'average_rating',
#        'total_sales', 'tax_status', 'tax_class', 'post_author', 'post_date',
#        'post_date_gmt', 'post_content', 'post_title', 'post_excerpt',
#        'post_status', 'comment_status', 'ping_status', 'post_password',
#        'post_name', 'post_modified', 'post_modified_gmt',
#        'post_content_filtered', 'post_parent', 'guid', 'menu_order',
#        'post_type', 'post_mime_type', 'comment_count'],
#       dtype='object')

# %%
erp.head()
# Out:
#    product_id  onsale_web  price  stock_quantity stock_status
# 0        3847           1   24.2               0   outofstock
# 1        3849           1   34.3               0   outofstock
# 2        3850           1   20.8               0   outofstock
# 3        4032           1   14.1               0   outofstock
# 4        4039           1   46.0               0   outofstock

# %%
liaison.head()
# Out:
#    product_id id_web
# 0        3847  15298
# 1        3849  15296
# 2        3850  15300
# 3        4032  19814
# 4        4039  19815

# %%
web.head()
# Out:
#                    sku  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros        0             0             0             0.0
# 1                15298        0             0             0             0.0
# 2                15296        0             0             0             0.0
# 3                15300        0             0             0             0.0
# 4                19814        0             0             0             0.0
#
#    total_sales tax_status  tax_class  post_author           post_date  ...  \
# 0         10.0    taxable        NaN          1.0 2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0 2018-02-08 12:58:52  ...
# 2          0.0    taxable        NaN          2.0 2018-02-08 13:49:41  ...
# 3          0.0    taxable        NaN          2.0 2018-02-08 14:08:36  ...
# 4          3.0    taxable        NaN          2.0 2018-02-09 14:01:05  ...
#
#                                            post_name       post_modified  \
# 0                             bon-cadeau-de-25-euros 2018-06-01 14:13:57
# 1        pierre-jean-villa-saint-joseph-preface-2018 2019-12-30 09:30:29
# 2          pierre-jean-villa-saint-joseph-tilde-2017 2019-12-21 09:00:17
# 3  pierre-jean-villa-croze-hermitage-accroche-coe... 2020-06-26 18:15:03
# 4                  pierre-jean-villa-igp-gamine-2018 2020-01-04 16:36:01
#
#     post_modified_gmt post_content_filtered post_parent  \
# 0 2018-06-01 12:13:57                   NaN         0.0
# 1 2019-12-30 08:30:29                   NaN         0.0
# 2 2019-12-21 08:00:17                   NaN         0.0
# 3 2020-06-26 16:15:03                   NaN         0.0
# 4 2020-01-04 15:36:01                   NaN         0.0
#
#                                                 guid menu_order  post_type  \
# 0  https://www.wine-spirit.fr/?post_type=product&...        0.0    product
# 1  https://www.wine-spirit.fr/?post_type=product&...        0.0    product
# 2  https://www.wine-spirit.fr/?post_type=product&...        0.0    product
# 3  https://www.wine-spirit.fr/?post_type=product&...        0.0    product
# 4  https://www.wine-spirit.fr/?post_type=product&...        0.0    product
#
#   post_mime_type comment_count
# 0            NaN           0.0
# 1            NaN           0.0
# 2            NaN           0.0
# 3            NaN           0.0
# 4            NaN           0.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### ANALYSES ET NETTOYAGE DES DONNEES ET JOINTURE DES DATASETS:
#
# On va dans un premier temps s'occuper des valeurs manquantes afin de faire le merge les datasets.
# On se rend compte dans un premier temps que le dataset erp n'a pas de valeurs manquantes et que le dataset liaison a 91 Nan dans la colonne id_web. Les product_id correspondant n'ont pas fait de ventes en ligne donc on peut également les supprimer du dataset.

# %%
print(erp.isna().sum(),'\n')   # 0 Nan -> Ok 
print(liaison.isna().sum())    # 91 Nan dans liaison.id_web --> on les supprime 
liaison.dropna(inplace=True)
print("liaison shape : {}".format(liaison.shape))
# Out:
# product_id        0
# onsale_web        0
# price             0
# stock_quantity    0
# stock_status      0
# dtype: int64
#
# product_id     0
# id_web        91
# dtype: int64
# liaison shape : (734, 2)

# %% [markdown]
# En regardant les valeurs de la colonne sku du dataset web on se rend compte que
# chaque ligne du dataset correspondant à une valeur dans sku est en double avec seulement quelques changements
# dans des colonnes qui n'ont pas d'utilités ici (i.e tax_status, post_type ou post_mime_type). On peut ainsi diviser la taille du dataset par 2 en ne gardant que les valeurs uniques de la colonne sku.

# %%
print(web.sku.value_counts(dropna=False))

web.sku.drop_duplicates().index                  #on recupère les index des valeurs uniques
web = web.iloc[web.sku.drop_duplicates().index]  # on récupère le dataset web avec les index des valeurs uniques

#on refait un point sur les dimensions:
print("les dimensions des datasets sont maintenant :\nerp : {}\nliason : {}\nweb : {}"
      .format(erp.shape,liaison.shape, web.shape))
# Out:
# NaN        85
# 14827.0     2
# 15526.0     2
# 16305.0     2
# 16306.0     2
#            ..
# 15145.0     2
# 15801.0     2
# 15452.0     2
# 15038.0     2
# 16230.0     2
# Name: sku, Length: 715, dtype: int64
# les dimensions des datasets sont maintenant :
# erp : (825, 5)
# liason : (734, 2)
# web : (715, 28)

# %% [markdown]
# Maintenant on va pouvoir faire le merge des datasets
# afin d'obtenir un dataset contenant toutes les informations nécessaires

# %%
# join les datasets liaison et erp via product_id
erp_liaison = pd.merge(liaison,erp, left_on='product_id',right_on='product_id', how='inner')

# merge le dataset erp_liaison avec le dataset web en indiquant que sku dans le dataset web correspond 
# à id_web dans le dataset erp_liaison
df_total = pd.merge(erp_liaison, web, how='inner', left_on='id_web',right_on='sku')

# %%
df_total.head()
# Out:
#    product_id id_web  onsale_web  price  stock_quantity stock_status    sku  \
# 0        3847  15298           1   24.2               0   outofstock  15298
# 1        3849  15296           1   34.3               0   outofstock  15296
# 2        3850  15300           1   20.8               0   outofstock  15300
# 3        4032  19814           1   14.1               0   outofstock  19814
# 4        4039  19815           1   46.0               0   outofstock  19815
#
#    virtual  downloadable  rating_count  ...  \
# 0        0             0             0  ...
# 1        0             0             0  ...
# 2        0             0             0  ...
# 3        0             0             0  ...
# 4        0             0             0  ...
#
#                                            post_name       post_modified  \
# 0        pierre-jean-villa-saint-joseph-preface-2018 2019-12-30 09:30:29
# 1          pierre-jean-villa-saint-joseph-tilde-2017 2019-12-21 09:00:17
# 2  pierre-jean-villa-croze-hermitage-accroche-coe... 2020-06-26 18:15:03
# 3                  pierre-jean-villa-igp-gamine-2018 2020-01-04 16:36:01
# 4          pierre-jean-villa-cote-rotie-carmina-2017 2020-01-04 16:36:10
#
#     post_modified_gmt  post_content_filtered  post_parent  \
# 0 2019-12-30 08:30:29                    NaN          0.0
# 1 2019-12-21 08:00:17                    NaN          0.0
# 2 2020-06-26 16:15:03                    NaN          0.0
# 3 2020-01-04 15:36:01                    NaN          0.0
# 4 2020-01-04 15:36:10                    NaN          0.0
#
#                                                 guid menu_order  post_type  \
# 0  https://www.wine-spirit.fr/?post_type=product&...        0.0    product
# 1  https://www.wine-spirit.fr/?post_type=product&...        0.0    product
# 2  https://www.wine-spirit.fr/?post_type=product&...        0.0    product
# 3  https://www.wine-spirit.fr/?post_type=product&...        0.0    product
# 4  https://www.wine-spirit.fr/?post_type=product&...        0.0    product
#
#   post_mime_type comment_count
# 0            NaN           0.0
# 1            NaN           0.0
# 2            NaN           0.0
# 3            NaN           0.0
# 4            NaN           0.0
#
# [5 rows x 34 columns]

# %% [markdown]
# Petit point sur les dimensions et valeurs du dataset total.
#
# Nous avons des valeurs manquantes ou nulles seulement dans des colonnes dont nous n'avons pas d'utilité ici.

# %%
print(df_total.isna().sum(), df_total.shape)
# Out:
# product_id                 0
# id_web                     0
# onsale_web                 0
# price                      0
# stock_quantity             0
# stock_status               0
# sku                        0
# virtual                    0
# downloadable               0
# rating_count               0
# average_rating             0
# total_sales                0
# tax_status                 0
# tax_class                714
# post_author                0
# post_date                  0
# post_date_gmt              0
# post_content             714
# post_title                 0
# post_excerpt               0
# post_status                0
# comment_status             0
# ping_status                0
# post_password            714
# post_name                  0
# post_modified              0
# post_modified_gmt          0
# post_content_filtered    714
# post_parent                0
# guid                       0
# menu_order                 0
# post_type                  0
# post_mime_type           714
# comment_count              0
# dtype: int64 (714, 34)

# %% [markdown]
# Regardons le chiffre d'affaire que ce marchand de vins a effectué

# %%
df_total.dtypes  # onsale_web, total_sales et price sont deja des nombres (float ou int) donc il n'y a rien 
                 # à modifier 

df_total['CA_par_produit_online'] = df_total.onsale_web*df_total.price
print("Le CA par produit vendu en ligne est de :\n{}"                     # Note that this is before taxes! 
      .format(df_total.CA_par_produit_online.sort_values(ascending=False)))
print("Le Chiffre d'Affaire réalisé en ligne est de : {} euros".format(df_total['CA_par_produit_online'].sum()))

print("Le Chiffre d'Affaire total réalisé est de : {} euros".format((df_total.total_sales*df_total.price).sum()))
# Out:
# Le CA par produit vendu en ligne est de :
# 199    225.0
# 426    217.5
# 587    191.3
# 218    176.0
# 553    175.0
#        ...
# 98       5.7
# 99       5.7
# 97       5.7
# 560      5.7
# 645      5.2
# Name: CA_par_produit_online, Length: 714, dtype: float64
# Le Chiffre d'Affaire réalisé en ligne est de : 23200.1 euros
# Le Chiffre d'Affaire total réalisé est de : 70568.6 euros

# %% [markdown]
# ### ANALYSES STATISTIQUES :

# %%
df_total.T
# Out:
#                                                                      0    \
# product_id                                                          3847
# id_web                                                             15298
# onsale_web                                                             1
# price                                                               24.2
# stock_quantity                                                         0
# stock_status                                                  outofstock
# sku                                                                15298
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          6.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2018-02-08 12:58:52
# post_date_gmt                                        2018-02-08 11:58:52
# post_content                                                         NaN
# post_title                   Pierre Jean Villa Saint-Joseph Préface 2018
# post_excerpt           Il exhale un nez subtil, racé avec du poivre f...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                    pierre-jean-villa-saint-joseph-preface-2018
# post_modified                                        2019-12-30 09:30:29
# post_modified_gmt                                    2019-12-30 08:30:29
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               24.2
#
#                                                                      1    \
# product_id                                                          3849
# id_web                                                             15296
# onsale_web                                                             1
# price                                                               34.3
# stock_quantity                                                         0
# stock_status                                                  outofstock
# sku                                                                15296
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2018-02-08 13:49:41
# post_date_gmt                                        2018-02-08 12:49:41
# post_content                                                         NaN
# post_title               Pierre Jean Villa Saint-Joseph Rouge Tildé 2017
# post_excerpt           Les vieilles vignes lui apportent une rare pro...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                      pierre-jean-villa-saint-joseph-tilde-2017
# post_modified                                        2019-12-21 09:00:17
# post_modified_gmt                                    2019-12-21 08:00:17
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               34.3
#
#                                                                      2    \
# product_id                                                          3850
# id_web                                                             15300
# onsale_web                                                             1
# price                                                               20.8
# stock_quantity                                                         0
# stock_status                                                  outofstock
# sku                                                                15300
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2018-02-08 14:08:36
# post_date_gmt                                        2018-02-08 13:08:36
# post_content                                                         NaN
# post_title             Pierre Jean Villa Crozes-Hermitage Accroche Co...
# post_excerpt           Dentelle de fruit de jeunes syrah, aux tanins ...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name              pierre-jean-villa-croze-hermitage-accroche-coe...
# post_modified                                        2020-06-26 18:15:03
# post_modified_gmt                                    2020-06-26 16:15:03
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               20.8
#
#                                                                      3    \
# product_id                                                          4032
# id_web                                                             19814
# onsale_web                                                             1
# price                                                               14.1
# stock_quantity                                                         0
# stock_status                                                  outofstock
# sku                                                                19814
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          3.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2018-02-09 14:01:05
# post_date_gmt                                        2018-02-09 13:01:05
# post_content                                                         NaN
# post_title             Pierre Jean Villa IGP Collines Rhodaniennes Ga...
# post_excerpt           Gamine représente tout le fruité et la gourman...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                              pierre-jean-villa-igp-gamine-2018
# post_modified                                        2020-01-04 16:36:01
# post_modified_gmt                                    2020-01-04 15:36:01
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               14.1
#
#                                                                      4    \
# product_id                                                          4039
# id_web                                                             19815
# onsale_web                                                             1
# price                                                               46.0
# stock_quantity                                                         0
# stock_status                                                  outofstock
# sku                                                                19815
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2018-02-12 09:04:37
# post_date_gmt                                        2018-02-12 08:04:37
# post_content                                                         NaN
# post_title                     Pierre Jean Villa Côte Rôtie Carmina 2017
# post_excerpt           Le côte rôtie Carmina monte en puissance mais ...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                      pierre-jean-villa-cote-rotie-carmina-2017
# post_modified                                        2020-01-04 16:36:10
# post_modified_gmt                                    2020-01-04 15:36:10
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               46.0
#
#                                                                      5    \
# product_id                                                          4040
# id_web                                                             15303
# onsale_web                                                             1
# price                                                               34.3
# stock_quantity                                                         0
# stock_status                                                  outofstock
# sku                                                                15303
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2018-02-12 09:13:35
# post_date_gmt                                        2018-02-12 08:13:35
# post_content                                                         NaN
# post_title             Pierre Jean Villa Saint-Joseph Saut De l'Ange ...
# post_excerpt           Roussanne finement exotique, atypique par sa v...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                  pierre-jean-villa-saint-joseph-saut-ange-2018
# post_modified                                        2019-11-02 13:25:07
# post_modified_gmt                                    2019-11-02 12:25:07
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               34.3
#
#                                                                      6    \
# product_id                                                          4041
# id_web                                                             14975
# onsale_web                                                             1
# price                                                               32.7
# stock_quantity                                                        15
# stock_status                                                     instock
# sku                                                                14975
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2018-02-12 09:45:14
# post_date_gmt                                        2018-02-12 08:45:14
# post_content                                                         NaN
# post_title                                 Pierre Gaillard Condrieu 2018
# post_excerpt           Un joli nez de fruits exotiques comme le litch...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                                  pierre-gaillard-condrieu-2018
# post_modified                                        2020-08-14 18:15:02
# post_modified_gmt                                    2020-08-14 16:15:02
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               32.7
#
#                                                                      7    \
# product_id                                                          4042
# id_web                                                             16042
# onsale_web                                                             1
# price                                                               31.2
# stock_quantity                                                        34
# stock_status                                                     instock
# sku                                                                16042
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          7.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2018-02-12 09:54:27
# post_date_gmt                                        2018-02-12 08:54:27
# post_content                                                         NaN
# post_title                                   Pierre Gaillard Cornas 2017
# post_excerpt           Une jolie robe grenat avec des reflets violacé...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                                    pierre-gaillard-cornas-2017
# post_modified                                        2020-08-14 10:15:02
# post_modified_gmt                                    2020-08-14 08:15:02
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               31.2
#
#                                                                      8    \
# product_id                                                          4043
# id_web                                                             14980
# onsale_web                                                             1
# price                                                               60.0
# stock_quantity                                                        12
# stock_status                                                     instock
# sku                                                                14980
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          3.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2018-02-12 10:03:05
# post_date_gmt                                        2018-02-12 09:03:05
# post_content                                                         NaN
# post_title              Pierre Gaillard Côte Rôtie Esprit de Blonde 2017
# post_excerpt           Complexité, finesse et subtilité sont au rende...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                   pierre-gaillard-cote-rotie-esprit-blond-2017
# post_modified                                        2020-08-24 14:00:03
# post_modified_gmt                                    2020-08-24 12:00:03
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               60.0
#
#                                                                      9    ...  \
# product_id                                                          4045  ...
# id_web                                                             16041  ...
# onsale_web                                                             1  ...
# price                                                               42.6  ...
# stock_quantity                                                        66  ...
# stock_status                                                     instock  ...
# sku                                                                16041  ...
# virtual                                                                0  ...
# downloadable                                                           0  ...
# rating_count                                                           0  ...
# average_rating                                                       0.0  ...
# total_sales                                                         14.0  ...
# tax_status                                                       taxable  ...
# tax_class                                                            NaN  ...
# post_author                                                          2.0  ...
# post_date                                            2018-02-12 10:09:03  ...
# post_date_gmt                                        2018-02-12 09:09:03  ...
# post_content                                                         NaN  ...
# post_title                               Pierre Gaillard Côte Rôtie 2018  ...
# post_excerpt           Ce vin exprime la diversité et l'équilibre ent...  ...
# post_status                                                      publish  ...
# comment_status                                                    closed  ...
# ping_status                                                       closed  ...
# post_password                                                        NaN  ...
# post_name                                pierre-gaillard-cote-rotie-2018  ...
# post_modified                                        2020-08-03 09:55:03  ...
# post_modified_gmt                                    2020-08-03 07:55:03  ...
# post_content_filtered                                                NaN  ...
# post_parent                                                          0.0  ...
# guid                   https://www.wine-spirit.fr/?post_type=product&...  ...
# menu_order                                                           0.0  ...
# post_type                                                        product  ...
# post_mime_type                                                       NaN  ...
# comment_count                                                        0.0  ...
# CA_par_produit_online                                               42.6  ...
#
#                                                                      704  \
# product_id                                                          6886
# id_web                                                             14897
# onsale_web                                                             1
# price                                                               42.0
# stock_quantity                                                         0
# stock_status                                                  outofstock
# sku                                                                14897
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2020-04-24 21:18:32
# post_date_gmt                                        2020-04-24 19:18:32
# post_content                                                         NaN
# post_title                                   Gratavinum Priorat GV5 2011
# post_excerpt           Couleur grenat très foncé, avec des reflets. U...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                                    gratavinum-priorat-gv5-2011
# post_modified                                        2020-06-26 15:05:03
# post_modified_gmt                                    2020-06-26 13:05:03
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               42.0
#
#                                                                      705  \
# product_id                                                          6887
# id_web                                                             15736
# onsale_web                                                             1
# price                                                               21.8
# stock_quantity                                                        24
# stock_status                                                     instock
# sku                                                                15736
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2020-04-24 21:32:59
# post_date_gmt                                        2020-04-24 19:32:59
# post_content                                                         NaN
# post_title                                   Gratavinum Priorat 2?r 2017
# post_excerpt           Le nez est intense, avec des notes de confitur...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                               gratavinum-priorat-2%cf%80r-2017
# post_modified                                        2020-06-24 11:45:03
# post_modified_gmt                                    2020-06-24 09:45:03
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               21.8
#
#                                                                      706  \
# product_id                                                          6920
# id_web                                                             15740
# onsale_web                                                             1
# price                                                               50.5
# stock_quantity                                                         1
# stock_status                                                     instock
# sku                                                                15740
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2020-04-25 12:32:17
# post_date_gmt                                        2020-04-25 10:32:17
# post_content                                                         NaN
# post_title               Château Jean Faure Saint-Emilion Grand Cru 2015
# post_excerpt           Une réussite absolue, jamais les cabernets ont...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                        jean-faure-saint-emilion-grand-cru-2015
# post_modified                                        2020-08-27 11:35:02
# post_modified_gmt                                    2020-08-27 09:35:02
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               50.5
#
#                                                                      707  \
# product_id                                                          6926
# id_web                                                             15845
# onsale_web                                                             1
# price                                                               49.9
# stock_quantity                                                        24
# stock_status                                                     instock
# sku                                                                15845
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          1.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2020-04-25 12:43:23
# post_date_gmt                                        2020-04-25 10:43:23
# post_content                                                         NaN
# post_title               Château Jean Faure Saint-Emilion Grand Cru 2016
# post_excerpt           Velouté, profond, racé, beaucoup de sève. Très...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                chateau-jean-faure-saint-emilion-grand-cru-2016
# post_modified                                        2020-07-20 17:09:23
# post_modified_gmt                                    2020-07-20 15:09:23
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               49.9
#
#                                                                      708  \
# product_id                                                          6928
# id_web                                                             15741
# onsale_web                                                             1
# price                                                               19.0
# stock_quantity                                                        20
# stock_status                                                     instock
# sku                                                                15741
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          2.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2020-04-25 12:49:49
# post_date_gmt                                        2020-04-25 10:49:49
# post_content                                                         NaN
# post_title                     Le Cèdre de Jean Faure Saint-Emilion 2016
# post_excerpt           Un nez ouvert  sur un velouté de fruits rouges...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                         cedre-de-jean-faure-saint-emilion-2016
# post_modified                                        2020-08-27 15:15:02
# post_modified_gmt                                    2020-08-27 13:15:02
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               19.0
#
#                                                                      709  \
# product_id                                                          6930
# id_web                                                             16135
# onsale_web                                                             1
# price                                                                8.4
# stock_quantity                                                        83
# stock_status                                                     instock
# sku                                                                16135
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          5.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2020-04-25 13:22:38
# post_date_gmt                                        2020-04-25 11:22:38
# post_content                                                         NaN
# post_title              Mouthes Le Bihan Côtes de Duras L'Aimé Chai 2015
# post_excerpt           Belle robe jeune à dominante rubis soutenue. N...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                                mouthes-le-bihan-aime-chai-2015
# post_modified                                        2020-08-26 17:35:03
# post_modified_gmt                                    2020-08-26 15:35:03
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                                8.4
#
#                                                                      710  \
# product_id                                                          7023
# id_web                                                             15891
# onsale_web                                                             1
# price                                                               27.5
# stock_quantity                                                        15
# stock_status                                                     instock
# sku                                                                15891
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2020-05-02 14:53:40
# post_date_gmt                                        2020-05-02 12:53:40
# post_content                                                         NaN
# post_title                    Camin Larredya Jurançon Sec La Virada 2018
# post_excerpt           L'exotisme du nez est complété par d'élégantes...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                     camin-larredya-jurancon-sec-la-virada-2018
# post_modified                                        2020-08-26 17:35:02
# post_modified_gmt                                    2020-08-26 15:35:02
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               27.5
#
#                                                                      711  \
# product_id                                                          7025
# id_web                                                             15887
# onsale_web                                                             1
# price                                                               69.0
# stock_quantity                                                         2
# stock_status                                                     instock
# sku                                                                15887
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2020-05-02 15:00:54
# post_date_gmt                                        2020-05-02 13:00:54
# post_content                                                         NaN
# post_title                Domaine Jamet Côte Rôtie Fructus Voluptas 2018
# post_excerpt           Pour cette cuvée, Jean-Paul Jamet recherche un...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                         jamet-cote-rotie-fructus-voluptas-2018
# post_modified                                        2020-08-14 18:15:03
# post_modified_gmt                                    2020-08-14 16:15:03
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               69.0
#
#                                                                      712  \
# product_id                                                          7247
# id_web                                                           13127-1
# onsale_web                                                             1
# price                                                               54.8
# stock_quantity                                                        23
# stock_status                                                     instock
# sku                                                              13127-1
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2020-06-09 15:42:04
# post_date_gmt                                        2020-06-09 13:42:04
# post_content                                                         NaN
# post_title                  Clos du Mont-Olivet Châteauneuf-du-Pape 2007
# post_excerpt           Nez gracieux, très élégant avec une touche flo...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name                 clos-du-mont-olivet-chateauneuf-du-pape-2007-2
# post_modified                                        2020-07-20 17:09:06
# post_modified_gmt                                    2020-07-20 15:09:06
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               54.8
#
#                                                                      713
# product_id                                                          7338
# id_web                                                             16230
# onsale_web                                                             1
# price                                                               16.3
# stock_quantity                                                        45
# stock_status                                                     instock
# sku                                                                16230
# virtual                                                                0
# downloadable                                                           0
# rating_count                                                           0
# average_rating                                                       0.0
# total_sales                                                          0.0
# tax_status                                                       taxable
# tax_class                                                            NaN
# post_author                                                          2.0
# post_date                                            2020-07-20 11:00:00
# post_date_gmt                                        2020-07-20 09:00:00
# post_content                                                         NaN
# post_title             Domaine Saint-Nicolas Vin de France Blanc Les ...
# post_excerpt           Issu d'un assemblage de chenin blanc et de cha...
# post_status                                                      publish
# comment_status                                                    closed
# ping_status                                                       closed
# post_password                                                        NaN
# post_name              domaine-saint-nicolas-fiefs-vendeens-blanc-les...
# post_modified                                        2020-08-13 10:45:03
# post_modified_gmt                                    2020-08-13 08:45:03
# post_content_filtered                                                NaN
# post_parent                                                          0.0
# guid                   https://www.wine-spirit.fr/?post_type=product&...
# menu_order                                                           0.0
# post_type                                                        product
# post_mime_type                                                       NaN
# comment_count                                                        0.0
# CA_par_produit_online                                               16.3
#
# [35 rows x 714 columns]

# %% [markdown]
# on voit que la quasi totalité des colonnes ne nous intéressent pas.
# On peut donc commencer par garder seulement les colonnes qui nous seront utiles : 'onsale_web', 'stock_quantity','total_sales' et 'price'

# %%
df = df_total.copy()
df = df[['onsale_web', 'stock_quantity','total_sales','price']]

# %% [markdown]
# #### METHODE DES INTERQUARTILES

# %%
X = df[['onsale_web', 'stock_quantity','total_sales']]
y = df.price

print("Description de X\n",X.describe())

Q1 = X.describe().values[4,:]
Q3 = X.describe().values[6,:]

print("Quartile 1 : {}" .format(Q1),
     "\nQuartile 3 : {}".format(Q3))
EQX = []
for i in range(Q1.size):
    EQX.append(Q3[i]-Q1[i])
    
print("Les équarts interquartiles du DataFrame X sont de :", EQX)
    
print("\nDescription de y\n",y.describe())
EQy = y.describe().values[6] - y.describe().values[4]
print("Les quartiles du vecteur y sont : \nQ1 = {},\nQ3 = {}".format(y.describe().values[4],y.describe().values[6])
      ,"\nL'écart inter quartile du vecteur y est de : ",EQy)
print("\nNombre de valeures comprises entre les deux quartiles :\n",
      y[(y>=y.describe().values[4]) & (y<=y.describe().values[6])].count())
# Out:
# Description de X
#         onsale_web  stock_quantity  total_sales
# count       714.0      714.000000   714.000000
# mean          1.0       28.746499     4.012605
# std           0.0       48.012608     8.518183
# min           1.0        0.000000     0.000000
# 25%           1.0        2.000000     0.000000
# 50%           1.0       12.000000     1.000000
# 75%           1.0       35.000000     4.000000
# max           1.0      578.000000    96.000000
# Quartile 1 : [1. 2. 0.]
# Quartile 3 : [ 1. 35.  4.]
# Les équarts interquartiles du DataFrame X sont de : [0.0, 33.0, 4.0]
#
# Description de y
#  count    714.000000
# mean      32.493137
# std       27.810525
# min        5.200000
# 25%       14.100000
# 50%       23.550000
# 75%       42.175000
# max      225.000000
# Name: price, dtype: float64
# Les quartiles du vecteur y sont :
# Q1 = 14.1,
# Q3 = 42.175000000000004
# L'écart inter quartile du vecteur y est de :  28.075000000000003
#
# Nombre de valeures comprises entre les deux quartiles :
#  357

# %% [markdown]
# Pour le vecteur y on trouve 179 valeurs de prix au dessus du 3ème quartile, 178 valeurs inférieures au 1er quartile et
# 357 valeurs comprises entre les deux quartiles. On voit que la répartition des valeurs est assez symétrique. Cependant
# on remarque que la différence entre les valeurs maximales et le quartile 3 sont bien plus grande que les différences
# entre les valeurs minimales et le quartile 1. On appuiera ainsi nos analyses statistiques autour des valeurs maximales
# pour trouver les outliers s'il y en a.

# %% [markdown]
# #### METHODE DU Z-SCORE :

# %%
# z score du vecteur prix y 

std_price = np.std(y)
zscore_price = stats.zscore(y)

# %%
print("std : ",std_price)
print("zscore :\n",zscore_price)
# Out:
# std :  27.791042941002935
# zscore :
#  0     -0.298410
# 1      0.065016
# 2     -0.420752
# 3     -0.661837
# 4      0.486015
#          ...
# 709   -0.866939
# 710   -0.179667
# 711    1.313620
# 712    0.802664
# 713   -0.582675
# Name: price, Length: 714, dtype: float64

# %%
# pour le premier élément, nous avons un zscore = -2.98410437e-01 ce qui signifie que cet élément est à 
#environ -0.3 #de la moyenne.

# On récupère les indices
result_1 = []
for element in zscore_price:
    if abs(element) > 2:
        result_1.append(zscore_price[zscore_price==element].index[0])

# %%
# En utilisant les index ci dessus, on obtient les prix des outliers : 
# les prix dont le z score à une valeur supérieure à 2
for i in result_1:
    print(y[i],'€')
# Out:
# 100.0 €
# 88.4 €
# 225.0 €
# 126.5 €
# 176.0 €
# 108.5 €
# 157.0 €
# 104.0 €
# 109.6 €
# 102.3 €
# 137.0 €
# 217.5 €
# 105.0 €
# 105.0 €
# 112.0 €
# 92.0 €
# 124.8 €
# 175.0 €
# 191.3 €
# 93.0 €
# 122.0 €
# 114.0 €
# 135.0 €
# 105.6 €
# 116.4 €
# 115.0 €
# 121.0 €
# 99.0 €
# 115.0 €
# 121.0 €

# %% [markdown]
# ### METHODE GRAPHIQUE:

# %% [markdown]
# #### BOXPLOT

# %%
plt.figure(figsize=(30,50))
plt.subplot(4,1,1)
a = sns.boxplot( y=df["price"], x=df["stock_quantity"]);
a.set_xlabel('stock_quantity',fontsize=30)
a.set_ylabel('price', fontsize=30)

plt.subplot(4,1,2)
b = sns.boxplot( y=df["price"], x=df["total_sales"]);
b.set_xlabel('total_sales',fontsize=30)
b.set_ylabel('price', fontsize=30)

plt.subplot(4,1,3)
c = sns.boxplot( y=df["price"], x=df["onsale_web"]);
c.set_xlabel('onsale_web',fontsize=30)
c.set_ylabel('price', fontsize=30)

plt.subplot(4,1,4)
d = sns.boxplot(y)
d.set_xlabel('price', fontsize=30)
# Out:
# Text(0.5, 0, 'price')

# %% [markdown]
# #### Analyse:
#
# Sur les Figures 1 et 2 (stock_quantity en fonction du prix et total_sales en fonction du prix): on voit que les produits avec un prix supérieur à 80€ sont moins vendus et ont un stock faible. Quant au produit moins chers (ayant un prix inférieur à 50€) on remarque que certains se vendent très bien et que d'autres se vendent peu.
#
# Sur les Figures 3 et 4 (onsale web en fonction du prix) on remarque que les produits les plus vendus sur le web sont ceux avec un prix inférieur à 50

# %% [markdown]
# #### NUAGES DE POINTS

# %%
#nuage de points 
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.scatter(data=df , y='price', x='total_sales', s='price', c='price')
plt.ylabel("Price")
plt.xlabel("Total sales")

plt.subplot(2,2,2)
plt.scatter(data=df , y='price', x='stock_quantity', s='price', c='price')
plt.ylabel("Price")
plt.xlabel("stock quantity")

plt.subplot(2,2,3)
plt.scatter(data=df , y='price', x='onsale_web', s='price', c='price')
plt.ylabel("Price")
plt.xlabel("onsale web")
# Out:
# Text(0.5, 0, 'onsale web')

# %% [markdown]
# De la même manière qu'avec les boxplots on remarque que les produits les plus chers sont les moins vendus
# et ceux avec un stock le plus faible. On voit cependant mieux sur ces graphiques les produits dont
# le nombre de ventes est très grands.

# %% [markdown]
# ### REGRESSION LINEAIRE

# %%
def linear_model(X,y):
    lm = LinearRegression()
    scaler = MinMaxScaler()
    
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=7)
    n_train = y_train.shape[0]
    n_val = y_test.shape[0]
    n_test = y_test.shape[0]
    print("total_train observations : %s" % n_train)
    print("total_test observations : %s" % n_test)
    scaler.fit_transform(X_train)
    scaler.transform(X_test)
    lm.fit(X_train,y_train)
    train_pred = lm.predict(X_train)
    test_pred = lm.predict(X_test)
    score = [r2_score(y_train,train_pred), r2_score(y_test,test_pred)]
    return score

# %%
score = linear_model(X,y)
print("R2 score sur le  training dataset : %s" % score[0])
print("R2 score sur le test dataset : %s" % score[1])
# Out:
# total_train observations : 535
# total_test observations : 179
# R2 score sur le  training dataset : 0.08346730839278471
# R2 score sur le test dataset : 0.10058133229881971

# %% [markdown]
# ### BONUS 1: CONSTRUCTION DE PROFIL A L'AIDE DES K-MEANS

# %%
#Cluster K-means
km=KMeans(n_clusters=4)
#adapter le modèle de données
km.fit_predict(X)
print(silhouette_score(X, km.labels_)) 

colormap=np.array(['Red','green','blue','yellow','orange'])
plt.scatter(X.stock_quantity, X.total_sales,s=40)
plt.scatter(X.stock_quantity, X.total_sales,c=colormap[km.labels_],s=40)
# Out:
# 0.6064653410348375

# %% [markdown]
# Grâce à la méthode k_means nous avons pu construire des clusters. Etant donnée qu'on ne connait pas le nombre de clusters optimal, nous avons choisi un nombre de 4. Nos données sont donc divisées en 4 clusters de couleurs différentes.
# Dans la partie qui va suivre, le but sera justement de déterminer le nombre optimal de clusters afin d'avoir une représentation significative.

# %% [markdown]
# ### BONUS 2 : OPTIMISATION DU NOMBRE DE CLUSTERS

# %% [markdown]
# #### METHODE ELBOW

# %%
# !pip install yellowbrick

# %%
from yellowbrick.cluster import KElbowVisualizer

km = KMeans()
# k is range of number of clusters.
visualizer = KElbowVisualizer(km, k=(2,10), timings= True)
# Fit data to visualizer
visualizer.fit(X)       
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
#Cluster K-means
km=KMeans(n_clusters=5)
#adapter le modèle de données
km.fit_predict(X)
print(silhouette_score(X, km.labels_)) 

colormap=np.array(['Red','green','blue','yellow','orange'])
plt.scatter(X.stock_quantity, X.total_sales,s=40)
plt.scatter(X.stock_quantity, X.total_sales,c=colormap[km.labels_],s=40)
# Out:
# 0.6041175076898337

# %% [markdown]
# Grace à la méthode Elbow, on voit que le nombre de cluster optimal est de 5.
